# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import metrics 
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro, binom
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison
import matplotlib.pyplot as plot
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from scipy import stats
from statsmodels.stats.power import ttest_power
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
import sys
import pylab as pl
import seaborn as sns

# %% [markdown]
# ## Q1: Import and store the data in a data frame. (2.5 points)

# %%
col_names = ['City1', 'City2', 'AverageFare', 'Distance', 'AvgWeeklyPassg', 'MktLeadingAirline','Mkt_share', 'AvgFare','Lowprice airline', 'marketshare', 'price']
airf = pd.read_fwf('http://users.stat.ufl.edu/~winner/data/airq402.dat', names=col_names)
airf
# Out:
#     City1 City2  AverageFare  Distance  AvgWeeklyPassg MktLeadingAirline  \
# 0     CAK   ATL       114.47       528          424.56                FL
# 1     CAK   MCO       122.47       860          276.84                FL
# 2     ALB   ATL       214.42       852          215.76                DL
# 3     ALB   BWI        69.40       288          606.84                WN
# 4     ALB   ORD       158.13       723          313.04                UA
# 5     ALB   FLL       135.17      1204          199.02                WN
# 6     ALB   LAS       152.85      2237          237.17                WN
# 7     ALB   LAX       190.73      2467          191.95                DL
# 8     ALB   MCO       129.35      1073          550.54                WN
# 9     ALB   TPA       134.17      1130          202.93                US
# 10    ABQ   ATL       212.49      1269          198.80                DL
# 11    ABQ   BWI       173.56      1670          312.39                WN
# 12    ABQ   ORD       170.67      1121          364.78                AA
# 13    ABQ   DFW       120.24       580          839.78                WN
# 14    ABQ   DEN       168.69       349          308.26                UA
# 15    ABQ   IAH       154.40       767          372.93                WN
# 16    ABQ   LAS       114.24       487          620.86                WN
# 17    ABQ   LAX       132.29       677          655.00                WN
# 18    ABQ   MSP       181.99       981          187.28                NW
# 19    ABQ   LGA       233.05      1825          344.45                AA
# 20    ABQ   OAK       162.21       889          388.15                WN
# 21    ABQ   MCO       161.74      1552          190.65                WN
# 22    ABQ   PHX        71.57       328         1252.39                WN
# 23    ABQ   PDX       163.63      1111          222.93                WN
# 24    ABQ   SAN       134.42       628          346.30                WN
# 25    ABQ   SEA       165.69      1180          284.34                WN
# 26    ABQ   TUS        77.82       321          191.19                WN
# 27    ABQ   IAD       227.93      1650          301.84                AA
# 28    AMA   DFW        74.82       324          615.10                WN
# 29    AMA   IAH       120.50       545          229.78                WN
# ..    ...   ...          ...       ...             ...               ...
# 970   SLC   SEA       110.64       689          892.39                DL
# 971   SLC   GEG        98.36       546          204.56                DL
# 972   SLC   IAD       263.37      1851          305.97                DL
# 973   SAT   SAN       165.13      1129          248.80                WN
# 974   SAT   SEA       177.77      1774          229.89                AA
# 975   SAT   IAD       215.04      1381          345.10                DL
# 976   SAN   SFO       122.02       447          937.93                UA
# 977   SAN   SJC        82.34       417         2176.19                WN
# 978   SAN   SEA       148.62      1050         1303.15                AS
# 979   SAN   TPA       177.91      2087          273.47                DL
# 980   SAN   TUS        74.62       367          469.67                WN
# 981   SAN   IAD       330.21      2276          582.17                UA
# 982   SFO   SNA       134.18       372          703.36                UA
# 983   SFO   SEA       116.78       678         1545.54                UA
# 984   SFO   TPA       237.26      2392          193.26                DL
# 985   SFO   IAD       401.23      2442          955.65                UA
# 986   SJC   SNA        77.11       342         1970.76                WN
# 987   SJC   SEA       105.84       697         1390.65                AS
# 988   SJC   TUS       144.22       721          204.56                AS
# 989   SJC   IAD       322.83      2424          229.02                UA
# 990   SNA   SEA       156.01       978         1191.84                AS
# 991   SEA   GEG        70.61       224         1423.15                AS
# 992   SEA   TPA       162.46      2520          312.93                DL
# 993   SEA   TUS       131.47      1216          359.23                AS
# 994   SEA   IAD       288.14      2329          787.50                UA
# 995   SYR   TPA       136.16      1104          184.34                US
# 996   TLH   TPA        83.28       200          232.71                FL
# 997   TPA   IAD       159.97       814          843.80                US
# 998   TPA   PBI        73.57       174          214.45                WN
# 999   IAD   PBI       126.67       859          475.65                US
#
#      Mkt_share  AvgFare Lowprice airline  marketshare   price
# 0        70.19   111.03               FL        70.19  111.03
# 1        75.10   123.09               DL        17.23  118.94
# 2        78.89   223.98               CO         2.77  167.12
# 3        96.97    68.86               WN        96.97   68.86
# 4        39.79   161.36               WN        15.34  145.42
# 5        40.68   137.97               DL        17.09  127.69
# 6        59.94   148.59               WN        59.94  148.59
# 7        17.89   205.06               US        16.59  174.00
# 8        76.84   127.69               WN        76.84  127.69
# 9        35.40   132.91               DL        26.40  124.78
# 10       68.39   226.79               AA        11.91  200.93
# 11       49.16   180.49               AA        14.37  161.39
# 12       45.94   174.62               WN        33.87  163.22
# 13       71.91   117.20               WN        71.91  117.20
# 14       59.55   181.34               F9        39.95  149.41
# 15       50.48   152.03               WN        50.48  152.03
# 16       93.92   113.82               WN        93.92  113.82
# 17       89.46   130.44               WN        89.46  130.44
# 18       65.00   182.27               CO         2.37  109.14
# 19       31.33   233.26               DL        19.50  222.08
# 20       88.63   164.27               HP         7.19  144.51
# 21       72.29   151.81               WN        72.29  151.81
# 22       77.65    70.99               WN        77.65   70.99
# 23       57.24   167.46               HP        20.77  155.82
# 24       82.92   136.70               HP        13.05  119.03
# 25       47.82   164.81               HP        25.07  159.64
# 26       86.29    73.50               WN        86.29   73.50
# 27       46.59   213.13               AA        46.59  213.13
# 28       82.04    71.51               WN        82.04   71.51
# 29       58.79   119.76               CO        37.55  118.05
# ..         ...      ...              ...          ...     ...
# 970      60.93   111.80               WN        36.44  105.36
# 971      62.27    97.48               DL        62.27   97.48
# 972      68.95   268.78               DL        68.95  268.78
# 973      57.92   165.01               AA        12.45  160.60
# 974      26.71   169.59               AA        26.71  169.59
# 975      48.59   191.34               DL        48.59  191.34
# 976      95.92   122.11               AA         1.35  102.68
# 977      71.53    83.52               AA        26.94   79.37
# 978      73.50   149.91               AS        73.50  149.91
# 979      27.10   172.14               WN        15.38  165.25
# 980      94.07    73.10               WN        94.07   73.10
# 981      42.55   440.35               AA        26.97  241.30
# 982      66.35   140.50               AA        30.82  119.80
# 983      52.32   122.59               AS        45.62  109.45
# 984      21.54   265.35               CO        16.02  200.96
# 985      64.45   490.03               TZ         3.78  182.66
# 986      49.97    77.54               AA        48.91   76.66
# 987      75.35   106.30               WN        22.04  103.02
# 988      56.16   143.53               AS        56.16  143.53
# 989      37.01   408.10               TZ        13.57  172.45
# 990      86.77   157.43               DL         2.19  100.08
# 991      68.40    72.60               WN        31.30   66.32
# 992      33.03   147.60               AA        23.75  141.21
# 993      73.25   126.38               AS        73.25  126.38
# 994      46.51   329.20               AS        30.43  252.34
# 995      33.37   135.82               DL        28.65  118.51
# 996      99.57    82.55               FL        99.57   82.55
# 997      46.19   159.65               DL        13.89  159.02
# 998      99.74    73.44               WN        99.74   73.44
# 999      56.28   129.92               DL        38.57  121.94
#
# [1000 rows x 11 columns]

# %% [markdown]
# ## Q2: Remove the outliers from the data (5 points)

# %%
airf.head()
print('Shape of Dataset Before removing the outliers:',airf.shape)

numeric_cols = airf.select_dtypes(include=[np.number]).columns.tolist()

for col in numeric_cols:
    sorted_col = airf.sort_values([col])
    q1, q3= np.percentile(sorted_col[col],[25,75])
    print(q1,q3)
    iqr = q3 - q1
    lower_bound = q1 -(1.5 * iqr) 
    upper_bound = q3 +(1.5 * iqr) 
    airf = airf.loc[(airf[col] > lower_bound) & (airf[col] < upper_bound)]

print('After Removal of outliers:',airf.shape)
# Out:
# Shape of Dataset Before removing the outliers: (1000, 11)
# 125.975 197.39249999999998
# 550.0 1399.0
# 256.95 768.04
# 46.7275 74.4725
# 126.165 202.805
# 13.06 52.98
# 115.84 167.81
# After Removal of outliers: (877, 11)

# %%
# Histogram to find the ourliers
airf.AverageFare.hist(bins=50)

# %%
# Boxplot to find the ourliers
airf.boxplot(column='AverageFare')

# %%
Q1 = airf['AverageFare'].quantile(0.25)
Q3 = airf['AverageFare'].quantile(0.75)
IQR = Q1-Q3

# %%
airf[airf.AverageFare > Q3 + 1.5*IQR]
# Out:
#     City1 City2  AverageFare  Distance  AvgWeeklyPassg MktLeadingAirline  \
# 0     CAK   ATL       114.47       528          424.56                FL
# 1     CAK   MCO       122.47       860          276.84                FL
# 2     ALB   ATL       214.42       852          215.76                DL
# 4     ALB   ORD       158.13       723          313.04                UA
# 5     ALB   FLL       135.17      1204          199.02                WN
# 6     ALB   LAS       152.85      2237          237.17                WN
# 7     ALB   LAX       190.73      2467          191.95                DL
# 8     ALB   MCO       129.35      1073          550.54                WN
# 9     ALB   TPA       134.17      1130          202.93                US
# 10    ABQ   ATL       212.49      1269          198.80                DL
# 11    ABQ   BWI       173.56      1670          312.39                WN
# 12    ABQ   ORD       170.67      1121          364.78                AA
# 13    ABQ   DFW       120.24       580          839.78                WN
# 14    ABQ   DEN       168.69       349          308.26                UA
# 15    ABQ   IAH       154.40       767          372.93                WN
# 16    ABQ   LAS       114.24       487          620.86                WN
# 17    ABQ   LAX       132.29       677          655.00                WN
# 18    ABQ   MSP       181.99       981          187.28                NW
# 19    ABQ   LGA       233.05      1825          344.45                AA
# 20    ABQ   OAK       162.21       889          388.15                WN
# 21    ABQ   MCO       161.74      1552          190.65                WN
# 23    ABQ   PDX       163.63      1111          222.93                WN
# 24    ABQ   SAN       134.42       628          346.30                WN
# 25    ABQ   SEA       165.69      1180          284.34                WN
# 27    ABQ   IAD       227.93      1650          301.84                AA
# 29    AMA   IAH       120.50       545          229.78                WN
# 30    ATL   AUS       205.24       812          377.50                DL
# 31    ATL   BWI       132.52       576         1453.91                DL
# 33    ATL   BUF       117.85       712          446.41                DL
# 34    ATL   CLT       233.63       227          292.50                DL
# ..    ...   ...          ...       ...             ...               ...
# 957   STL   SLC       162.77      1156          239.23                AA
# 958   STL   SAT       168.89       786          256.73                AA
# 959   STL   SAN       184.88      1558          385.21                AA
# 960   STL   SFO       213.11      1736          345.10                AA
# 961   STL   SNA       232.97      1570          228.04                AA
# 962   STL   SEA       215.62      1710          355.21                AA
# 963   STL   TPA       156.14       869          444.56                AA
# 965   STL   IAD       194.58       719          645.54                AA
# 966   SLC   SAN       120.89       626          547.17                DL
# 967   SLC   SFO       142.71       599          404.78                DL
# 968   SLC   SJC       143.99       585          239.02                DL
# 969   SLC   SNA       102.95       588          548.69                DL
# 970   SLC   SEA       110.64       689          892.39                DL
# 971   SLC   GEG        98.36       546          204.56                DL
# 973   SAT   SAN       165.13      1129          248.80                WN
# 974   SAT   SEA       177.77      1774          229.89                AA
# 975   SAT   IAD       215.04      1381          345.10                DL
# 976   SAN   SFO       122.02       447          937.93                UA
# 978   SAN   SEA       148.62      1050         1303.15                AS
# 979   SAN   TPA       177.91      2087          273.47                DL
# 982   SFO   SNA       134.18       372          703.36                UA
# 984   SFO   TPA       237.26      2392          193.26                DL
# 987   SJC   SEA       105.84       697         1390.65                AS
# 988   SJC   TUS       144.22       721          204.56                AS
# 990   SNA   SEA       156.01       978         1191.84                AS
# 992   SEA   TPA       162.46      2520          312.93                DL
# 993   SEA   TUS       131.47      1216          359.23                AS
# 995   SYR   TPA       136.16      1104          184.34                US
# 997   TPA   IAD       159.97       814          843.80                US
# 999   IAD   PBI       126.67       859          475.65                US
#
#      Mkt_share  AvgFare Lowprice airline  marketshare   price
# 0        70.19   111.03               FL        70.19  111.03
# 1        75.10   123.09               DL        17.23  118.94
# 2        78.89   223.98               CO         2.77  167.12
# 4        39.79   161.36               WN        15.34  145.42
# 5        40.68   137.97               DL        17.09  127.69
# 6        59.94   148.59               WN        59.94  148.59
# 7        17.89   205.06               US        16.59  174.00
# 8        76.84   127.69               WN        76.84  127.69
# 9        35.40   132.91               DL        26.40  124.78
# 10       68.39   226.79               AA        11.91  200.93
# 11       49.16   180.49               AA        14.37  161.39
# 12       45.94   174.62               WN        33.87  163.22
# 13       71.91   117.20               WN        71.91  117.20
# 14       59.55   181.34               F9        39.95  149.41
# 15       50.48   152.03               WN        50.48  152.03
# 16       93.92   113.82               WN        93.92  113.82
# 17       89.46   130.44               WN        89.46  130.44
# 18       65.00   182.27               CO         2.37  109.14
# 19       31.33   233.26               DL        19.50  222.08
# 20       88.63   164.27               HP         7.19  144.51
# 21       72.29   151.81               WN        72.29  151.81
# 23       57.24   167.46               HP        20.77  155.82
# 24       82.92   136.70               HP        13.05  119.03
# 25       47.82   164.81               HP        25.07  159.64
# 27       46.59   213.13               AA        46.59  213.13
# 29       58.79   119.76               CO        37.55  118.05
# 30       75.72   212.59               AA        10.36  193.01
# 31       67.61   138.42               FL        26.56  118.54
# 33       46.06   123.55               FL        46.01  110.49
# 34       69.26   234.85               US        30.02  229.85
# ..         ...      ...              ...          ...     ...
# 957      54.70   165.97               WN        33.62  152.93
# 958      77.47   167.11               AA        77.47  167.11
# 959      68.59   183.02               WN        17.21  174.98
# 960      81.32   214.91               US         1.22  142.84
# 961      82.36   233.39               UA         5.14  205.04
# 962      76.37   218.32               UA         9.05  189.66
# 963      62.17   154.49               AA        62.17  154.49
# 965      89.19   198.82               US         2.76  122.68
# 966      73.14   119.81               DL        73.14  119.81
# 967      63.10   146.29               UA        33.83  133.85
# 968      78.94   150.10               WN        17.23  114.46
# 969      89.93   101.01               DL        89.93  101.01
# 970      60.93   111.80               WN        36.44  105.36
# 971      62.27    97.48               DL        62.27   97.48
# 973      57.92   165.01               AA        12.45  160.60
# 974      26.71   169.59               AA        26.71  169.59
# 975      48.59   191.34               DL        48.59  191.34
# 976      95.92   122.11               AA         1.35  102.68
# 978      73.50   149.91               AS        73.50  149.91
# 979      27.10   172.14               WN        15.38  165.25
# 982      66.35   140.50               AA        30.82  119.80
# 984      21.54   265.35               CO        16.02  200.96
# 987      75.35   106.30               WN        22.04  103.02
# 988      56.16   143.53               AS        56.16  143.53
# 990      86.77   157.43               DL         2.19  100.08
# 992      33.03   147.60               AA        23.75  141.21
# 993      73.25   126.38               AS        73.25  126.38
# 995      33.37   135.82               DL        28.65  118.51
# 997      46.19   159.65               DL        13.89  159.02
# 999      56.28   129.92               DL        38.57  121.94
#
# [792 rows x 11 columns]

# %% [markdown]
# ## Q3: Treat “Average Fare” – 3rdColumn as your Dependent Variable and Rest of the columns as Independent Variable. (2.5 points)

# %%
#features = ['City1','City2', 'Distance', 'AvgWeeklyPassg', 'MktLeadingAirline','Mkt share', 'Avg Fare','Low price airline', 'market share', 'price']
features = ['Distance', 'price','AvgWeeklyPassg', 'Mkt_share', 'AvgFare']

#Independent Variable 
y = airf['AverageFare']

#Dependent Variable 
x = airf[features]
print(x)
print(y)
# Out:
#      Distance   price  AvgWeeklyPassg  Mkt_share  AvgFare
# 0         528  111.03          424.56      70.19   111.03
# 1         860  118.94          276.84      75.10   123.09
# 2         852  167.12          215.76      78.89   223.98
# 3         288   68.86          606.84      96.97    68.86
# 4         723  145.42          313.04      39.79   161.36
# 5        1204  127.69          199.02      40.68   137.97
# 6        2237  148.59          237.17      59.94   148.59
# 7        2467  174.00          191.95      17.89   205.06
# 8        1073  127.69          550.54      76.84   127.69
# 9        1130  124.78          202.93      35.40   132.91
# 10       1269  200.93          198.80      68.39   226.79
# 11       1670  161.39          312.39      49.16   180.49
# 12       1121  163.22          364.78      45.94   174.62
# 13        580  117.20          839.78      71.91   117.20
# 14        349  149.41          308.26      59.55   181.34
# 15        767  152.03          372.93      50.48   152.03
# 16        487  113.82          620.86      93.92   113.82
# 17        677  130.44          655.00      89.46   130.44
# 18        981  109.14          187.28      65.00   182.27
# 19       1825  222.08          344.45      31.33   233.26
# 20        889  144.51          388.15      88.63   164.27
# 21       1552  151.81          190.65      72.29   151.81
# 22        328   70.99         1252.39      77.65    70.99
# 23       1111  155.82          222.93      57.24   167.46
# 24        628  119.03          346.30      82.92   136.70
# 25       1180  159.64          284.34      47.82   164.81
# 26        321   73.50          191.19      86.29    73.50
# 27       1650  213.13          301.84      46.59   213.13
# 28        324   71.51          615.10      82.04    71.51
# 29        545  118.05          229.78      58.79   119.76
# ..        ...     ...             ...        ...      ...
# 962      1710  189.66          355.21      76.37   218.32
# 963       869  154.49          444.56      62.17   154.49
# 964       351   72.64          228.91      66.14    72.64
# 965       719  122.68          645.54      89.19   198.82
# 966       626  119.81          547.17      73.14   119.81
# 967       599  133.85          404.78      63.10   146.29
# 968       585  114.46          239.02      78.94   150.10
# 969       588  101.01          548.69      89.93   101.01
# 970       689  105.36          892.39      60.93   111.80
# 971       546   97.48          204.56      62.27    97.48
# 973      1129  160.60          248.80      57.92   165.01
# 974      1774  169.59          229.89      26.71   169.59
# 975      1381  191.34          345.10      48.59   191.34
# 976       447  102.68          937.93      95.92   122.11
# 978      1050  149.91         1303.15      73.50   149.91
# 979      2087  165.25          273.47      27.10   172.14
# 980       367   73.10          469.67      94.07    73.10
# 982       372  119.80          703.36      66.35   140.50
# 984      2392  200.96          193.26      21.54   265.35
# 987       697  103.02         1390.65      75.35   106.30
# 988       721  143.53          204.56      56.16   143.53
# 990       978  100.08         1191.84      86.77   157.43
# 991       224   66.32         1423.15      68.40    72.60
# 992      2520  141.21          312.93      33.03   147.60
# 993      1216  126.38          359.23      73.25   126.38
# 995      1104  118.51          184.34      33.37   135.82
# 996       200   82.55          232.71      99.57    82.55
# 997       814  159.02          843.80      46.19   159.65
# 998       174   73.44          214.45      99.74    73.44
# 999       859  121.94          475.65      56.28   129.92
#
# [877 rows x 5 columns]
# 0      114.47
# 1      122.47
# 2      214.42
# 3       69.40
# 4      158.13
# 5      135.17
# 6      152.85
# 7      190.73
# 8      129.35
# 9      134.17
# 10     212.49
# 11     173.56
# 12     170.67
# 13     120.24
# 14     168.69
# 15     154.40
# 16     114.24
# 17     132.29
# 18     181.99
# 19     233.05
# 20     162.21
# 21     161.74
# 22      71.57
# 23     163.63
# 24     134.42
# 25     165.69
# 26      77.82
# 27     227.93
# 28      74.82
# 29     120.50
#         ...
# 962    215.62
# 963    156.14
# 964     75.34
# 965    194.58
# 966    120.89
# 967    142.71
# 968    143.99
# 969    102.95
# 970    110.64
# 971     98.36
# 973    165.13
# 974    177.77
# 975    215.04
# 976    122.02
# 978    148.62
# 979    177.91
# 980     74.62
# 982    134.18
# 984    237.26
# 987    105.84
# 988    144.22
# 990    156.01
# 991     70.61
# 992    162.46
# 993    131.47
# 995    136.16
# 996     83.28
# 997    159.97
# 998     73.57
# 999    126.67
# Name: AverageFare, Length: 877, dtype: float64

# %%
airf.isnull().sum()
# Out:
# City1                0
# City2                0
# AverageFare          0
# Distance             0
# AvgWeeklyPassg       0
# MktLeadingAirline    0
# Mkt_share            0
# AvgFare              0
# Lowprice airline     0
# marketshare          0
# price                0
# dtype: int64

# %% [markdown]
# ## Q4: Drop the independent variables which has less than 0.1 correlation with the dependent variable (5 points)

# %%
airf.corr()
# Out:
#                 AverageFare  Distance  AvgWeeklyPassg  Mkt_share   AvgFare  \
# AverageFare        1.000000  0.512280       -0.194769  -0.202205  0.979853
# Distance           0.512280  1.000000       -0.123024  -0.546091  0.480295
# AvgWeeklyPassg    -0.194769 -0.123024        1.000000   0.018146 -0.160751
# Mkt_share         -0.202205 -0.546091        0.018146   1.000000 -0.188915
# AvgFare            0.979853  0.480295       -0.160751  -0.188915  1.000000
# marketshare       -0.498025 -0.361306        0.074210   0.280194 -0.522616
# price              0.837329  0.531995       -0.206307  -0.309026  0.790611
#
#                 marketshare     price
# AverageFare       -0.498025  0.837329
# Distance          -0.361306  0.531995
# AvgWeeklyPassg     0.074210 -0.206307
# Mkt_share          0.280194 -0.309026
# AvgFare           -0.522616  0.790611
# marketshare        1.000000 -0.261714
# price             -0.261714  1.000000

# %%
airf.columns
# Out:
# Index(['City1', 'City2', 'AverageFare', 'Distance', 'AvgWeeklyPassg',
#        'MktLeadingAirline', 'Mkt_share', 'AvgFare', 'Lowprice airline',
#        'marketshare', 'price'],
#       dtype='object')

# %%
airf.head()
# Out:
#   City1 City2  AverageFare  Distance  AvgWeeklyPassg MktLeadingAirline  \
# 0   CAK   ATL       114.47       528          424.56                FL
# 1   CAK   MCO       122.47       860          276.84                FL
# 2   ALB   ATL       214.42       852          215.76                DL
# 3   ALB   BWI        69.40       288          606.84                WN
# 4   ALB   ORD       158.13       723          313.04                UA
#
#    Mkt_share  AvgFare Lowprice airline  marketshare   price
# 0      70.19   111.03               FL        70.19  111.03
# 1      75.10   123.09               DL        17.23  118.94
# 2      78.89   223.98               CO         2.77  167.12
# 3      96.97    68.86               WN        96.97   68.86
# 4      39.79   161.36               WN        15.34  145.42

# %%
airf = airf.drop(['AvgWeeklyPassg','Mkt_share','marketshare'], axis=1)

# %%
airf.head()
# Out:
#   City1 City2  AverageFare  Distance MktLeadingAirline  AvgFare  \
# 0   CAK   ATL       114.47       528                FL   111.03
# 1   CAK   MCO       122.47       860                FL   123.09
# 2   ALB   ATL       214.42       852                DL   223.98
# 3   ALB   BWI        69.40       288                WN    68.86
# 4   ALB   ORD       158.13       723                UA   161.36
#
#   Lowprice airline   price
# 0               FL  111.03
# 1               DL  118.94
# 2               CO  167.12
# 3               WN   68.86
# 4               WN  145.42

# %%
sns.heatmap(airf.corr(), annot=True)
plot.show()

# %% [markdown]
# ## Q5: Create scatter Plot of Independent Variable vs Dependent Variable. (2.5 points)

# %%
sns.pairplot(airf,x_vars=['Distance', 'price','AvgWeeklyPassg', 'Mkt_share', 'AvgFare'],y_vars=['AverageFare'],kind='reg',size=7,aspect=0.7)
# Out:
# C:\Users\ABHIJEET\Anaconda4\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Q6: Divide the data set into training and test data set and build a Multiple Linear Regression model. (5 points)

# %%
# Dividing data for training and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=10)

# %%
#Fit Multiple linear Regression Model
initfit=LinearRegression()
model = initfit.fit(x_train,y_train)
pred = model.predict(x_test)
print('LinearRegression Values:', model)
print('Predicted data for test:', pred)
# Out:
# LinearRegression Values: LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)
# Predicted data for test: [242.21275476 159.72849545 101.18581349 128.850907   131.96627668
#  163.14404146 111.985582   184.49710164 158.64661352 149.78625003
#  143.29090878 174.13561392 220.15549156 133.01219368 140.88598816
#  147.41615285 157.48324388 127.23743597 205.01282277 112.17756317
#  153.7802218  155.67314875 183.54098658 223.99380191 214.1220871
#  103.3786025  222.15930083 151.20015505 169.5058841  133.80072522
#  179.44211617 188.99657576 134.70628565 161.07489225 250.90446391
#  144.90686963  70.8356072   57.54399679 136.87134053 116.36268644
#   82.08202792 106.0742243   76.64489633 184.03443445 117.93914145
#  156.74359014 106.6275044  129.54375819  62.21955403 209.55227913
#  170.1456675  107.20377579 120.9554054  157.82162326 125.41118076
#  250.28406021 216.15604117 250.43906296 210.88307084 187.90310951
#  173.30720559 187.66091112  84.39263937 131.24404035 156.10089248
#   74.89144304 130.64810919 186.41169417 145.1886245  149.97502113
#  191.9592697  237.04652034 169.29972406 135.41313986 201.88784177
#  101.99627414 154.60557121 155.46636204 166.07447976 123.91940604
#  163.63086877 187.34198806 155.74571622 217.60896476 209.71740753
#  199.04387366  74.01600392 259.54918235 201.45025764 148.24024314
#  195.31224108 114.68328032 131.88570679 157.34136053 227.52580429
#  169.92560741 130.79349167 119.6517851  152.2682221  212.29035642
#  263.11030507 215.38806199 107.38300109  65.46576676 134.05616534
#  237.87729356 204.29625363 142.07825396 129.24133956 128.70506807
#  167.40943475 133.16335488 192.56958732 111.45107613 218.58301259
#  185.88906841  74.44604521 169.14947302 267.46819747 169.65937768
#   97.16526429 175.13097034 172.26268649  95.11961009 227.33814574
#  239.27342246 215.38053296 225.06671683 127.65463821 214.95042225
#  111.73054672 123.35452408 123.96913975 192.10531449 235.02317125
#  240.38275581 212.56545387 222.24405696  85.87575418 228.19920137
#  156.45942697 166.87525956 134.25436033 146.91985059 162.78142824
#  117.07164037 212.71070123 217.58159398 176.37344624 164.94687795
#  201.45774556 135.7704907  148.02448424 131.69652236  79.86682044
#  170.12651685 168.49493539 200.85918774 111.67354876 150.93431957
#  195.14263058  86.48296875 129.76380506 207.77833713  86.81715964
#  208.17186636 129.25315548 130.73183988 144.3534269  221.68200522
#  165.57893306 202.32977868 171.99178614 172.64268362 174.63328952
#  240.18463534 196.92593677 136.64318161 202.08744642 207.90096022
#  118.96774116 140.78054186 168.02658634 166.16335496 129.27100375
#  257.06916513 154.23266683 169.92948998 215.97748855  90.8400759
#  263.88466928 129.98563964 133.42496768 106.79240994  88.97194496
#  183.90996131  73.47885353 191.41621604 153.46101831 224.00533722
#  268.86207147 173.50001176 106.71687304 285.5816512  192.03917435
#  209.48021513 166.46330618  82.27914554 190.88628809 109.39156423
#  180.77461184  73.74701663 140.04543575 159.30457    199.46672727
#  182.68735995 265.68837616 123.00743768 140.01803964 116.20776413]

# %% [markdown]
# ## Q7: Print the coefficients & intercepts of the linear regression model (5 points)

# %%
print('Coefficients:',model.coef_)
print('Intercepts',model.intercept_)
# Out:
# Coefficients: [ 0.00311455  0.18974749 -0.00365479  0.06002375  0.75915686]
# Intercepts 5.049743288984985

# %% [markdown]
# ## Q8: Print the accuracy of the overall model (2.5 points)

# %%
#Performance of overall model
# calculate MAE, MSE, RMSE
print(metrics.mean_absolute_error(y_test, pred))
print(metrics.mean_squared_error(y_test, pred))
print(np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# 5.798607289928338
# 75.41022493248785
# 8.683906087267863
